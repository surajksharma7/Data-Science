# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
import matplotlib.pyplot as plt

# %%
data = {
    "R&D Spend": [165.0, 101.0, 29.0],
    "Administration": [137.0, 92.0, 127.0],
    "Marketing Spend": [472.0, 250.0, 201.0],
    "Profit": [192.0, 144.0, 91.0]
}

df = pd.DataFrame(data, index=[0, 11, 36])

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 0       165.0           137.0            472.0   192.0
# 11      101.0            92.0            250.0   144.0
# 36       29.0           127.0            201.0    91.0

# %%
df['F0'] = df['Profit'].mean()

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit          F0
# 0       165.0           137.0            472.0   192.0  142.333333
# 11      101.0            92.0            250.0   144.0  142.333333
# 36       29.0           127.0            201.0    91.0  142.333333

# %%
df['Residual'] = df['Profit'] - df["F0"]

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit          F0   Residual
# 0       165.0           137.0            472.0   192.0  142.333333  49.666667
# 11      101.0            92.0            250.0   144.0  142.333333   1.666667
# 36       29.0           127.0            201.0    91.0  142.333333 -51.333333

# %%
from sklearn.tree import DecisionTreeRegressor

X = df[['R&D Spend', 'Administration', 'Marketing Spend']]
y_residual = df['Residual']

tree = DecisionTreeRegressor(max_depth=1)
tree.fit(X, y_residual)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(model)
# Out:
# [Text(0.5, 0.75, 'x[2] <= 225.5\nsquared_error = 1701.556\nsamples = 3\nvalue = 142.333'),
#  Text(0.25, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 91.0'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'squared_error = 576.0\nsamples = 2\nvalue = 168.0'),
#  Text(0.625, 0.5, '  False')]

# %%
learning_rate = 0.1
df['F1'] = df['F0'] + learning_rate * tree.predict(X)

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit          F0   Residual  \
# 0       165.0           137.0            472.0   192.0  142.333333  49.666667
# 11      101.0            92.0            250.0   144.0  142.333333   1.666667
# 36       29.0           127.0            201.0    91.0  142.333333 -51.333333
#
#        F1
# 0   144.9
# 11  144.9
# 36  137.2

# %%
# Assume X_new is new data you want to predict
X_new = pd.DataFrame({
    'R&D Spend': [120, 50],
    'Administration': [100, 110],
    'Marketing Spend': [300, 150]
})

# Start with F0
y_pred = np.full(len(X_new), FO)

# Add each tree's contribution (assuming you have a list of trained trees)
learning_rate = 0.1
for tree in list_of_trained_trees:
    y_pred += learning_rate * tree.predict(X_new)

print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 9
#       2 X_new = pd.DataFrame({
#       3     'R&D Spend': [120, 50],
#       4     'Administration': [100, 110],
#       5     'Marketing Spend': [300, 150]
#       6 })
#       8 # Start with F0
# ----> 9 y_pred = np.full(len(X_new), FO)
#      11 # Add each tree's contribution (assuming you have a list of trained trees)
#      12 learning_rate = 0.1
#
# NameError: name 'FO' is not defined
